# %%
from EMsolver.solver import EMsolver
from RBG_Maxwell.Plasma.utils import find_largest_time_steps
from Particle_transport.main import pic_transport
import cupy
import numpy as np
from RBG_Maxwell.Unit_conversion.main import unit_conversion
import time
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/35/v4ln6fyj2q75t864d3snd7c80000gn/T/ipykernel_41569/1335670915.py in <module>
# ----> 1 from EMsolver.solver import EMsolver
#       2 from RBG_Maxwell.Plasma.utils import find_largest_time_steps
#       3 from Particle_transport.main import pic_transport
#       4 import cupy
#       5 import numpy as np
#
# ~/文章投稿/JefiPIC/EMsolver/__init__.py in <module>
#       1 from . import region_distance
# ----> 2 from . import cuda_functions
#       3 from . import solver
#
# ~/文章投稿/JefiPIC/EMsolver/cuda_functions.py in <module>
# ----> 1 import cupy
#       2 from numba import cuda
#       3 import math
#       4
#       5 # give the distance between two grids
#
# ModuleNotFoundError: No module named 'cupy'

# %% [markdown]
# # Flexible Unit conversion

# %%
# Unit conversion table
hbar, c, lambdax, epsilon0 = 1.1822579826363647e-07, 2.9979090484247153, 1.386275612896618e-15, 90631227428685.16
conversion_table = \
unit_conversion('SI_to_LHQCD', coef_J_to_E=lambdax, hbar=hbar, c=c, k=1., epsilon0=epsilon0)
conversion_table_reverse = \
unit_conversion('LHQCD_to_SI', coef_J_to_E=lambdax, hbar=hbar, c=c, k=1., epsilon0=epsilon0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/35/v4ln6fyj2q75t864d3snd7c80000gn/T/ipykernel_41569/2812163984.py in <module>
#       2 hbar, c, lambdax, epsilon0 = 1.1822579826363647e-07, 2.9979090484247153, 1.386275612896618e-15, 90631227428685.16
#       3 conversion_table = \
# ----> 4 unit_conversion('SI_to_LHQCD', coef_J_to_E=lambdax, hbar=hbar, c=c, k=1., epsilon0=epsilon0)
#       5 conversion_table_reverse = \
#       6 unit_conversion('LHQCD_to_SI', coef_J_to_E=lambdax, hbar=hbar, c=c, k=1., epsilon0=epsilon0)
#
# NameError: name 'unit_conversion' is not defined

# %%
# conversion_table
 'Joules': 721357276069008.8, 
 'meter': 15541.21524167369,
 'second': 1554125418846.7249,
 'kilogram': 7.213621991693117e+30,
 'Kelvin': 9.959419232046767e-09,
 'Ampere': 6893696364.342851,
 'Coulomb': 1.0713703277570692e+22,
 'Tesla': 0.00043324057020635494,
 'Volt/m': 4.3323823077185345e-12,
 'momentum': 7.2135991123851805e+22,
 'force': 46415823388.27953,
 'unit charge': 1716.5208017963178
# Out:
#   File "/var/folders/35/v4ln6fyj2q75t864d3snd7c80000gn/T/ipykernel_41569/2852941384.py", line 2
#     'Joules': 721357276069008.8,
#     ^
# IndentationError: unexpected indent

# %%
conversion_table_reverse
 'TO_Joules': 1.386275612896618e-15,
 'TO_meter': 6.434503251190454e-05,
 'TO_second': 6.434487126155323e-13,
 'TO_kilogram': 1.3862661519435797e-31,
 'TO_Kelvin': 100407461.18832567,
 'TO_Ampere': 1.4506005880566894e-10,
 'TO_Coulomb': 9.333840728009668e-23,
 'TO_Tesla': 2308.186418284175,
 'TO_Volt/m': 230819888221.4085,
 'TO_momentum': 1.3862705487515643e-23,
 'TO_force': 2.154437704648174e-11,
 'TO_unit charge': 0.0005825737730375958

# %% [markdown]
# # initial variables

# %%
# Physical parameters
macro_particle = 0.1
charges = [-1.60217733e-19*conversion_table['Coulomb']*macro_particle] # unit in Coulomb
masses = [9.1093897e-31*conversion_table['kilogram']*macro_particle] # unit in kg
number_charges = [macro_particle]

# Grid initial
# Grid boundary
x_left_bound_o, y_left_bound_o, z_left_bound_o = 0, 0, 0 # Observation
x_left_bound_s, y_left_bound_s, z_left_bound_s = x_left_bound_o, y_left_bound_o, z_left_bound_o # Source

# Grid size
dx, dy, dz = 1e-5*conversion_table['meter'], 1e-5*conversion_table['meter'], 1e-5*conversion_table['meter']
dx_o, dy_o, dz_o = dx, dy, dz # Observation
dx_s, dy_s, dz_s = dx_o, dy_o, dz_o # Source

# Space size
nx, ny, nz = 1, 251, 111
x_grid_size_o, y_grid_size_o, z_grid_size_o = nx, ny, nz
x_grid_size_s, y_grid_size_s, z_grid_size_s = x_grid_size_o, y_grid_size_o, z_grid_size_o

# Computing time
total_comp_time = 1.0 * 1.0e-9*conversion_table['second'] # unit in second
n_step = 5000
dt = total_comp_time/n_step # unit in second

# particle initial
initial_energy = 10 # electron velocity in unit of eV
initial_velocity = 1 * 3*10**8*np.sqrt(1 - (1 / (1 + initial_energy/510000)**2))*conversion_table['meter']/conversion_table['second'] # electron velocity in unit of m/s
total_charge = -0.5e-13 * conversion_table['Coulomb'] # unit in Coulomb
number_of_particles = int(total_charge/charges[0]) + 1 # Number of macro particles

# Set the positions of all the particles in x, y, and z axes separately
pos_x = (0 + 1 * np.random.random(number_of_particles)) * dx
pos_y = (9 + 1 * np.random.random(number_of_particles)) * dy
pos_z = (5 + 101 * np.random.random(number_of_particles)) * dz
pos = {0: np.array([pos_x, pos_y, pos_z]).transpose()} # Positions of all the particles

# Set the velocities of all the particles in x, y, and z axes separately
v_x = np.zeros(number_of_particles)
v_y = initial_velocity * np.ones(number_of_particles)
v_z = np.zeros(number_of_particles)
velocity = {0: np.array([v_x, v_y, v_z]).transpose()} # Velocities of all the particles

# %%
# Diagnose the parameters in the Flexible Unit
dt*initial_velocity,\
total_charge/number_of_particles,\
number_of_particles,\ # Number of the macro-particles
pos_x,\ # x-positions of all the particles
pos_y,\ # y-positions of all the particles
pos_z,\ # z-positions of all the particles
v_x,\ # Velocities along the x axis of all the particles
v_y,\ # Velocities along the y axis of all the particles
v_z,\ # Velocities along the z axis of all the particles
dx,dy,dz # Grid size
# Out:
# (0.005839286026880107,
#  -171.65248009889103,
#  3120754,
#  array([0.1029261 , 0.05355925, 0.0219568 , ..., 0.11767319, 0.15121879,
#         0.0843367 ]),
#  array([1.40920202, 1.44631981, 1.45658665, ..., 1.45472475, 1.47816652,
#         1.53446769]),
#  array([ 9.44250372,  2.67622614, 15.85657967, ...,  9.27990611,
#          7.20916306,  8.8321621 ]),
#  array([0., 0., 0., ..., 0., 0., 0.]),
#  array([0.01878641, 0.01878641, 0.01878641, ..., 0.01878641, 0.01878641,
#         0.01878641]),
#  array([0., 0., 0., ..., 0., 0., 0.]),
#  0.15541215241673692,
#  0.15541215241673692,
#  0.15541215241673692)

# %%
# set up the number of time snapshots to be saved
len_time_snapshots = min(find_largest_time_steps(dx_o, dy_o, dz_o, \
                                                 x_left_bound_o, y_left_bound_o, z_left_bound_o, \
                                                 dx_s, dy_s, dz_s, \
                                                 x_left_bound_s, y_left_bound_s, z_left_bound_s, \
                                                 x_grid_size_o, y_grid_size_o, z_grid_size_o, \
                                                 x_grid_size_s, y_grid_size_s, z_grid_size_s,\
                                                 dt, c), 10000)

# %% [markdown]
# # Initialize the code

# %%
# Initialize the partile transport module
PIC = pic_transport(pos, velocity, dt, charges, number_charges, masses, \
                    x_left_bound_o, y_left_bound_o, z_left_bound_o, nx, ny, nz, dx_s, dy_s, dz_s)

# %%
# Initialize the electromagnetic field Jefimenko's equations solver
PIC_provider = EMsolver(len_time_snapshots, \
                        x_grid_size_o, y_grid_size_o, z_grid_size_o, \
                        x_grid_size_s, y_grid_size_s, z_grid_size_s, \
                        dx_o, dy_o, dz_o, x_left_bound_o, y_left_bound_o, z_left_bound_o, \
                        dx_s, dy_s, dz_s, x_left_bound_s, y_left_bound_s, z_left_bound_s, \
                        dt, epsilon0, c)

# %% [markdown]
# # Plasma evolution

# %%
n_steps = (n_step + 1) # total_comp_time_step
diagnose_point = n_steps//100 # Save the results up to 100 diagnosing points
print_point = n_steps//10 # Print the progress per 10%
# Create the diagnosing list
electron_rho = []
EMfield = []
current_rho = []
pos_save = []
velocity_save = []
num_rho = []

# Start the time
start_time = time.time()
print('The total time step is around {}'.format(n_steps))
for i_step in range(n_steps):
    
    ##########################################################################
    rho_to_Jefi, Jx_to_Jefi, Jy_to_Jefi, Jz_to_Jefi = PIC.evaluate_rho_J(dx, dy, dz, nx, ny, nz)
    ##########################################################################
   
    rho, Jx, Jy, Jz = rho_to_Jefi.flatten(), \
                      Jx_to_Jefi.flatten(), \
                      Jy_to_Jefi.flatten(), \
                      Jz_to_Jefi.flatten()
    
    PIC_provider.Jefimenko_solver(rho, Jx, Jy, Jz)
    
    # atrack EM fields
    Ex, Ey, Ez, Bx, By, Bz = PIC_provider.acquire_EB_field()

    # Add a external magnetic field
    By += 10*conversion_table['Tesla'] 

    # proceed particle transport
    PIC.proceed_one_step(Ex, Ey, Ez, Bx, By, Bz, dx, dy, dz, nx, ny, nz)
    
    if i_step%print_point == 0 or i_step == n_steps:
        print('calculating the {}-th time step'.format(i_step),', finished {}% '.format(100*(i_step+1)/n_steps))
    
    if i_step%diagnose_point == 0 or i_step == n_steps:       
        current_rho.append([Jx_to_Jefi.get(), Jy_to_Jefi.get(), Jz_to_Jefi.get()])
        electron_rho.append(rho_to_Jefi.get())
        for i_key in pos.keys():
            pos_save.append(PIC.pos[i_key].get())
            velocity_save.append(PIC.velocity[i_key].get())
        num_rho.append(PIC.evaluate_n_nu(dx, dy, dz, nx, ny, nz).get())
        EMfield.append([Ex.get(), Ey.get(), Ez.get(), Bx.get(), By.get(), Bz.get()])

# End the time
end_time = time.time()
t_time = end_time - start_time # Give the total computing time
# Out:
# The total time step is around 5001
# calculating the 0-th time step , finished 0.01999600079984003%
# calculating the 50-th time step , finished 1.0197960407918416%
# calculating the 100-th time step , finished 2.019596080783843%
# calculating the 150-th time step , finished 3.019396120775845%
# calculating the 200-th time step , finished 4.019196160767846%
# calculating the 250-th time step , finished 5.018996200759848%
# calculating the 300-th time step , finished 6.01879624075185%
# calculating the 350-th time step , finished 7.018596280743851%
# calculating the 400-th time step , finished 8.018396320735853%
# calculating the 450-th time step , finished 9.018196360727854%
# calculating the 500-th time step , finished 10.017996400719856%
# calculating the 550-th time step , finished 11.017796440711857%
# calculating the 600-th time step , finished 12.01759648070386%
# calculating the 650-th time step , finished 13.017396520695861%
# calculating the 700-th time step , finished 14.017196560687863%
# calculating the 750-th time step , finished 15.016996600679864%
# calculating the 800-th time step , finished 16.016796640671867%
# calculating the 850-th time step , finished 17.016596680663866%
# calculating the 900-th time step , finished 18.01639672065587%
# calculating the 950-th time step , finished 19.01619676064787%
# calculating the 1000-th time step , finished 20.015996800639872%
# calculating the 1050-th time step , finished 21.015796840631875%
# calculating the 1100-th time step , finished 22.015596880623875%
# calculating the 1150-th time step , finished 23.015396920615878%
# calculating the 1200-th time step , finished 24.015196960607877%
# calculating the 1250-th time step , finished 25.01499700059988%
# calculating the 1300-th time step , finished 26.014797040591883%
# calculating the 1350-th time step , finished 27.014597080583883%
# calculating the 1400-th time step , finished 28.014397120575886%
# calculating the 1450-th time step , finished 29.014197160567885%
# calculating the 1500-th time step , finished 30.01399720055989%
# calculating the 1550-th time step , finished 31.013797240551888%
# calculating the 1600-th time step , finished 32.01359728054389%
# calculating the 1650-th time step , finished 33.013397320535894%
# calculating the 1700-th time step , finished 34.0131973605279%
# calculating the 1750-th time step , finished 35.01299740051989%
# calculating the 1800-th time step , finished 36.012797440511896%
# calculating the 1850-th time step , finished 37.0125974805039%
# calculating the 1900-th time step , finished 38.0123975204959%
# calculating the 1950-th time step , finished 39.012197560487905%
# calculating the 2000-th time step , finished 40.0119976004799%
# calculating the 2050-th time step , finished 41.011797640471904%
# calculating the 2100-th time step , finished 42.01159768046391%
# calculating the 2150-th time step , finished 43.01139772045591%
# calculating the 2200-th time step , finished 44.011197760447914%
# calculating the 2250-th time step , finished 45.01099780043991%
# calculating the 2300-th time step , finished 46.01079784043191%
# calculating the 2350-th time step , finished 47.010597880423916%
# calculating the 2400-th time step , finished 48.01039792041592%
# calculating the 2450-th time step , finished 49.01019796040792%
# calculating the 2500-th time step , finished 50.00999800039992%
# calculating the 2550-th time step , finished 51.00979804039192%
# calculating the 2600-th time step , finished 52.009598080383924%
# calculating the 2650-th time step , finished 53.00939812037593%
# calculating the 2700-th time step , finished 54.00919816036792%
# calculating the 2750-th time step , finished 55.008998200359926%
# calculating the 2800-th time step , finished 56.00879824035193%
# calculating the 2850-th time step , finished 57.00859828034393%
# calculating the 2900-th time step , finished 58.008398320335935%
# calculating the 2950-th time step , finished 59.00819836032793%
# calculating the 3000-th time step , finished 60.007998400319934%
# calculating the 3050-th time step , finished 61.00779844031194%
# calculating the 3100-th time step , finished 62.00759848030394%
# calculating the 3150-th time step , finished 63.00739852029594%
# calculating the 3200-th time step , finished 64.00719856028795%
# calculating the 3250-th time step , finished 65.00699860027994%
# calculating the 3300-th time step , finished 66.00679864027195%
# calculating the 3350-th time step , finished 67.00659868026395%
# calculating the 3400-th time step , finished 68.00639872025594%
# calculating the 3450-th time step , finished 69.00619876024795%
# calculating the 3500-th time step , finished 70.00599880023995%
# calculating the 3550-th time step , finished 71.00579884023195%
# calculating the 3600-th time step , finished 72.00559888022396%
# calculating the 3650-th time step , finished 73.00539892021595%
# calculating the 3700-th time step , finished 74.00519896020796%
# calculating the 3750-th time step , finished 75.00499900019996%
# calculating the 3800-th time step , finished 76.00479904019195%
# calculating the 3850-th time step , finished 77.00459908018397%
# calculating the 3900-th time step , finished 78.00439912017596%
# calculating the 3950-th time step , finished 79.00419916016797%
# calculating the 4000-th time step , finished 80.00399920015997%
# calculating the 4050-th time step , finished 81.00379924015196%
# calculating the 4100-th time step , finished 82.00359928014397%
# calculating the 4150-th time step , finished 83.00339932013597%
# calculating the 4200-th time step , finished 84.00319936012798%
# calculating the 4250-th time step , finished 85.00299940011998%
# calculating the 4300-th time step , finished 86.00279944011197%
# calculating the 4350-th time step , finished 87.00259948010398%
# calculating the 4400-th time step , finished 88.00239952009598%
# calculating the 4450-th time step , finished 89.00219956008799%
# calculating the 4500-th time step , finished 90.00199960007998%
# calculating the 4550-th time step , finished 91.00179964007198%
# calculating the 4600-th time step , finished 92.00159968006399%
# calculating the 4650-th time step , finished 93.00139972005599%
# calculating the 4700-th time step , finished 94.001199760048%
# calculating the 4750-th time step , finished 95.00099980003999%
# calculating the 4800-th time step , finished 96.00079984003199%
# calculating the 4850-th time step , finished 97.000599880024%
# calculating the 4900-th time step , finished 98.000399920016%
# calculating the 4950-th time step , finished 99.000199960008%
# calculating the 5000-th time step , finished 100.0%

# %%
t_time

# %% [markdown]
# # Data analysis

# %%
# Spatial distribution
import matplotlib.pyplot as plt
xi, yi = np.mgrid[1:252:1,1:112:1]
fig, axes = plt.subplots(ncols=5, nrows=5, figsize = (15,10))
for jj in range(5):
    for kk in range(5):        
        axes[jj,kk].pcolormesh(xi, yi, num_rho[jj*20+kk*4+2][0])

# %%
# Fields waveforms
Ey = np.array([EMfield[1][1].reshape([nx,ny,nz])[0,i,55] for i in range(251)])*conversion_table_reverse['TO_Volt/m']
te = np.linspace(0,1.0,num=len(EMfield))*dt*n_steps*1e9*conversion_table_reverse['TO_second']
plt.plot(te, Ey, color='red', marker='o', label='Ey V/m')
plt.legend(loc='best')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2935315/155517525.py in <module>
#       1 Ey = np.array([EMfield[1][1].reshape([nx,ny,nz])[0,i,55] for i in range(251)])*conversion_table_reverse['TO_Volt/m']
#       2 te = np.linspace(0,1.0,num=len(EMfield))*dt*n_steps*1e9*conversion_table_reverse['TO_second']
# ----> 3 plt.plot(te, Ey, color='red', marker='o', label='Ey V/m')
#       4 plt.legend(loc='best')
#       5 plt.show()
#
# ~/anaconda3/envs/RBG-Maxwell/lib/python3.8/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
#    2758         *args, scalex=scalex, scaley=scaley,
#    2759         **({"data": data} if data is not None else {}), **kwargs)
#
# ~/anaconda3/envs/RBG-Maxwell/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
#    1634             self.add_line(line)
#
# ~/anaconda3/envs/RBG-Maxwell/lib/python3.8/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# ~/anaconda3/envs/RBG-Maxwell/lib/python3.8/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     496
#     497         if x.shape[0] != y.shape[0]:
# --> 498             raise ValueError(f"x and y must have same first dimension, but "
#     499                              f"have shapes {x.shape} and {y.shape}")
#     500         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (101,) and (251,)

# %%
Ey = np.array([EMfield[i][1].reshape([nx,ny,nz])[0,80,55] for i in range(len(EMfield))])*conversion_table_reverse['TO_Volt/m']
te = np.linspace(0,1.0,num=len(EMfield))*dt*n_steps*1e9*conversion_table_reverse['TO_second']
plt.plot(te, Ey, color='red', marker='o', label='Ey V/m')
plt.legend(loc='best')
plt.show()

# %%
Ey = np.array([EMfield[i][1].reshape([nx,ny,nz])[0,210,55] for i in range(len(EMfield))])*conversion_table_reverse['TO_Volt/m']
te = np.linspace(0,1.0,num=len(EMfield))*dt*n_steps*1e9*conversion_table_reverse['TO_second']
plt.plot(te, Ey, color='red', marker='o', label='Ey V/m')
plt.legend(loc='best')
plt.show()

# %%
Jy1 = np.array([current_rho[i][1][0,15,55] for i in range(len(current_rho))])*\
conversion_table_reverse['TO_Ampere']/conversion_table_reverse['TO_meter']**2
tj = np.linspace(0,1,num=len(current_rho))*dt*n_steps*1e9*conversion_table_reverse['TO_second']
plt.plot(tj, Jy1, color='red', marker='o', label='Jy@[0,50,55] A/m^2')
plt.legend(loc='best')
plt.show()

# %%
y = np.array([current_rho[i][1][0,210,55] for i in range(len(current_rho))])*\
conversion_table_reverse['TO_Ampere']/conversion_table_reverse['TO_meter']**2
tj = np.linspace(0,1,num=len(electron_rho))*dt*n_steps*1e9*conversion_table_reverse['TO_second']
plt.plot(tj, y, color='red', marker='o', label='Jy@[0,210,55] A/m^2')
plt.legend(loc='best')
plt.show()

# %%
rhoy =np.array([electron_rho[i][0,12,55] for i in range(len(electron_rho))])*\
conversion_table_reverse['TO_Coulomb']/conversion_table_reverse['TO_meter']**3
trho = np.linspace(1,100,num=len(electron_rho))*dt*conversion_table_reverse['TO_second']*100*10**9
plt.plot(trho, rhoy, color='red', marker='o', label='rho@[0,50,55] C/m^3')
plt.legend(loc='best')
plt.show()

# %%
# f = open('Ey.txt','w')
# # f.write('time/ns \t Ey/(V/m) \n')
# for i in range(len(te)):
#         f.write(str(te[i]) + ' \t')
#         f.write(str(Ey[i]) + ' \n')     
# f.close()

# f = open('Jy.txt','w')
# f.write('time/ns \t Jy/(A/m2) \n')
# for i in range(len(tj)):
#         f.write(str(tj[i]) + ' \t')
#         f.write(str(Jy[i]) + ' \n')     
# f.close()

# f = open('rho.txt','w')
# f.write('time/ns \t Ey/(V/m) \n')
# for i in range(len(trho)):
#         f.write(str(trho[i]) + ' \t')
#         f.write(str(rhoy[i]) + ' \n')     
# f.close()     

# f = open('0.0ns.txt', 'w')
# for i in range(27861):
#         f.write(str(np.array(num_rho)[0][0].flatten()[i]*macro_particle/conversion_table_reverse['TO_meter']**3) + '\n')
# f.close()

# f = open('0.2ns.txt', 'w')
# for i in range(27861):
#         f.write(str(np.array(num_rho)[20][0].flatten()[i]*macro_particle/conversion_table_reverse['TO_meter']**3) + '\n')
# f.close()

# f = open('0.4ns.txt', 'w')
# for i in range(27861):
#         f.write(str(np.array(num_rho)[40][0].flatten()[i]*macro_particle/conversion_table_reverse['TO_meter']**3) + '\n')
# f.close()

# f = open('0.6ns.txt', 'w')
# for i in range(27861):
#         f.write(str(np.array(num_rho)[60][0].flatten()[i]*macro_particle/conversion_table_reverse['TO_meter']**3) + '\n')
# f.close()

f = open('0.8ns.txt', 'w')
for i in range(27861):
        f.write(str(np.array(num_rho)[80][0].flatten()[i]*macro_particle/conversion_table_reverse['TO_meter']**3) + '\n')
f.close()

# f = open('1.0ns.txt', 'w')
# for i in range(27861):
#         f.write(str(np.array(num_rho)[100][0].flatten()[i]*macro_particle/conversion_table_reverse['TO_meter']**3) + '\n')
# f.close()
